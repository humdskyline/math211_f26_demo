# %% [markdown]
# ### <a href="https://data8.org/sp26/reference/"> Python Reference Link <a>
#
# Run the cell below so that we can set our modules up

# %%
import numpy as np
from datascience import *
import math

# %% [markdown]
# ### What would Python do?
#
# Run the following cell to define the Arrays

# %%
odd = make_array(1, 3, 5, 7)
even = np.arange(2, 10, 2)
nums = make_array('1', '2', '3', '4')

# %% [markdown]
# #### Now run the following cells to see if your predictions are correct!

# %%
odd

# %%
even

# %%
nums

# %%
odd + even

# %%
odd + nums

# %%
even.item(3) + odd.item(1)

# %%
odd * 3

# %%
even - odd

# %%
nums.item(3) + "0"

# %%
sum(odd > 4)

# %%
sum(odd > 4) / len(odd > 4)

# %% [markdown]
# ### Now let's look at some high temperatures
#
# Run the following cell to define the Array

# %%
temps = make_array(72, 68, 75, 63, 66)

# %% [markdown]
# ### Let's take a look at the function np.diff()
# ![image.png](attachment:f5de0361-df05-4a35-bdc5-1bf9e4966dca.png)
#
# Run the following cell.  How do the results compare with the changes you calculated on your worksheet

# %%
np.diff(temps)

# %% [markdown]
# ### Now we are ready to find the biggest decrease in temperature
#
# Write the code for that
