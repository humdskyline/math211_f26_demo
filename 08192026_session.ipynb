# %% [markdown]
# # Welcome to Jupyter Notebooks!

# %% [markdown]
# ### Checklist for each time you open a notebook file:
# 1. Toggle Line Numbers 'On'
# 2. Run all previous cells (if you are continuing your work from before)

# %% [markdown]
# ### Click the following Hyperlink for the: [Python Reference Page](https://data8.org/su26/reference/)

# %% [markdown]
# ### Run the following cell to load the Python modules we will need in this notebook

# %%
import numpy as np
from datascience import *
import math

# %% [markdown]
# ## What will Python do??
# Check your predictions by running the following cells

# %%
4 + 5
# Out:
# 9

# %%
4+5.0
# Out:
# 9.0

# %%
"4" + "5"
# Out:
# '45'

# %%
3*"Hi"
# Out:
# 'HiHiHi'

# %%
Print("Hello")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 Print("Hello")
#
# NameError: name 'Print' is not defined

# %%
message = "Hello"
print(message)
# Out:
# Hello

# %% [markdown]
# ## To begin exploring our class survey, we first need to load the dataset into a Table
#
# ### Run the following cell

# %%
link = "https://raw.githubusercontent.com/humdskyline/data/main/first_class_survey_f2026.csv"
first_survey = Table.read_table(link)

# %% [markdown]
# ### The first thing we should always to is to see what the first five rows of the Table look like

# %%
first_survey.show(5)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>career</th> <th>sem_completed</th> <th>units_taking</th> <th>work_hours</th> <th>sleep_hours</th> <th>commute_min</th> <th>coding_exp</th> <th>data_exp</th> <th>ds_confidence</th> <th>think_time</th> <th>ds_field</th> <th>color</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Research/Science         </td> <td>3            </td> <td>11          </td> <td>40        </td> <td>7          </td> <td>10         </td> <td>1         </td> <td>1       </td> <td>8            </td> <td>Afternoon </td> <td>Science & Research           </td> <td>Green </td>
#         </tr>
#         <tr>
#             <td>Government/Public Service</td> <td>12           </td> <td>3           </td> <td>40        </td> <td>7          </td> <td>30         </td> <td>1         </td> <td>3       </td> <td>6            </td> <td>Morning   </td> <td>Public Policy & Social Issues</td> <td>Purple</td>
#         </tr>
#         <tr>
#             <td>Not Sure Yet             </td> <td>2            </td> <td>9           </td> <td>32        </td> <td>6          </td> <td>15         </td> <td>1         </td> <td>1       </td> <td>6            </td> <td>Late Night</td> <td>I'm not sure yet             </td> <td>Purple</td>
#         </tr>
#         <tr>
#             <td>administration of justice</td> <td>2            </td> <td>13          </td> <td>17        </td> <td>7          </td> <td>15         </td> <td>2         </td> <td>2       </td> <td>4            </td> <td>Afternoon </td> <td>Business & Marketing         </td> <td>Blue  </td>
#         </tr>
#         <tr>
#             <td>Engineering              </td> <td>1            </td> <td>12.5        </td> <td>15        </td> <td>5          </td> <td>8          </td> <td>1         </td> <td>1       </td> <td>10           </td> <td>Late Night</td> <td>Healthcare & Medicine        </td> <td>Purple</td>
#         </tr>
#     </tbody>
# </table>
# <p>... (23 rows omitted)</p>

# %% [markdown]
# ### We can see what all of the column names are

# %%
first_survey.labels
# Out:
# ('career',
#  'sem_completed',
#  'units_taking',
#  'work_hours',
#  'sleep_hours',
#  'commute_min',
#  'coding_exp',
#  'data_exp',
#  'ds_confidence',
#  'think_time',
#  'ds_field',
#  'color')

# %% [markdown]
# # Submitting Notebooks

# %% [markdown]
# Download your notebook in an  HTML, and then upload that HTML file to Canvas.
